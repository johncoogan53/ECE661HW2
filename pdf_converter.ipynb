# %% [markdown]
# <a href="https://colab.research.google.com/github/johncoogan53/ECE661HW2/blob/main/pdf_converter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#will convert ipynb files ot pdf files

# %%
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic
# !sudo apt-get install pandoc
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   dvisvgm fonts-droid-fallback fonts-lato fonts-lmodern fonts-noto-mono
#   fonts-texgyre fonts-urw-base35 libapache-pom-java libcommons-logging-java
#   libcommons-parent-java libfontbox-java libfontenc1 libgs9 libgs9-common
#   libidn12 libijs-0.35 libjbig2dec0 libkpathsea6 libpdfbox-java libptexenc1
#   libruby3.0 libsynctex2 libteckit0 libtexlua53 libtexluajit2 libwoff1
#   libzzip-0-13 lmodern poppler-data preview-latex-style rake ruby
#   ruby-net-telnet ruby-rubygems ruby-webrick ruby-xmlrpc ruby3.0
#   rubygems-integration t1utils teckit tex-common tex-gyre texlive-base
#   texlive-binaries texlive-latex-base texlive-latex-extra
#   texlive-latex-recommended texlive-pictures tipa xfonts-encodings
#   xfonts-utils
# Suggested packages:
#   fonts-noto fonts-freefont-otf | fonts-freefont-ttf libavalon-framework-java
# ...

# %%
pip install --upgrade nbconvert jupyter
# Out:
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.4/257.4 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 79.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 21.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 4.1 MB/s eta 0:00:00
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# ...

# %%
# !jupyter nbconvert --to pdf /content/drive/MyDrive/ColabNotebooks/ECE661\ HW\ 1\ John\ Coogan.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/ColabNotebooks/ECE661 HW 1 John Coogan.ipynb to pdf
# [NbConvertApp] Support files will be in ECE661 HW 1 John Coogan_files/
# [NbConvertApp] Making directory ./ECE661 HW 1 John Coogan_files
# [NbConvertApp] Writing 70847 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 351854 bytes to /content/drive/MyDrive/ColabNotebooks/ECE661 HW 1 John Coogan.pdf
