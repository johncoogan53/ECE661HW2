# %% [markdown]
# # Replicating CIFAR-10 Analysis with ResNet-20

# %%
# import necessary dependencies
import argparse
import os, sys
import time
import datetime
from tqdm import tqdm_notebook as tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

from tools.dataset import CIFAR10
from torch.utils.data import DataLoader

import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# >Check Cuda

# %%
print(torch.__version__)
# Check CUDA version supported by PyTorch
print("CUDA version supported by PyTorch:", torch.version.cuda)
# Out:
# 2.4.1+cu124
# CUDA version supported by PyTorch: 12.4

# %%
def check_cuda():
    if torch.cuda.is_available():
        print(
            "CUDA is available. You have", torch.cuda.device_count(), "CUDA device(s)."
        )
        for i in range(torch.cuda.device_count()):
            print(f"Device {i}: {torch.cuda.get_device_name(i)}")
    else:
        print("CUDA is not available.")


check_cuda()
# Out:
# CUDA is available. You have 1 CUDA device(s).
# Device 0: NVIDIA GeForce RTX 3050 Ti Laptop GPU

# %%
# define the SimpleNN mode;
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 8, 5)
        self.bn1 = nn.BatchNorm2d(8)
        self.conv2 = nn.Conv2d(8, 16, 3)
        self.bn2 = nn.BatchNorm2d(16)
        self.fc1 = nn.Linear(16 * 6 * 6, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)
        self.silu = nn.SiLU()

    def forward(self, x):
        out = self.silu(self.bn1(self.conv1(x)))
        out = F.max_pool2d(out, 2)
        out = self.silu(self.bn2(self.conv2(out)))
        out = F.max_pool2d(out, 2)
        out = out.view(out.size(0), -1)
        out = self.silu(self.fc1(out))
        out = self.silu(self.fc2(out))
        out = self.fc3(out)
        return out

# %% [markdown]
# > pre-processing from simpleNN

# %%
mean = (0.4914, 0.4822, 0.4465)
std = (0.2023, 0.1994, 0.2010)

transform_train = transforms.Compose(
    [
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean, std),
    ]
)

transform_val = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize(mean, std)]
)

# %% [markdown]
# >Dataloader

# %%
DATA_ROOT = "./data"
TRAIN_BATCH_SIZE = 128
VAL_BATCH_SIZE = 100

train_set = CIFAR10(
    root=DATA_ROOT, mode="train", download=True, transform=transform_train
)
val_set = CIFAR10(root=DATA_ROOT, mode="val", download=True, transform=transform_val)

# construct dataloader
train_loader = DataLoader(
    train_set,
    batch_size=TRAIN_BATCH_SIZE,
    shuffle=True,
    num_workers=4,
)
val_loader = DataLoader(
    val_set,
    batch_size=VAL_BATCH_SIZE,
    shuffle=False,
    num_workers=4,
)
# Out:
# Using downloaded and verified file: ./data\cifar10_trainval_F22.zip
# Extracting ./data\cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified
# Using downloaded and verified file: ./data\cifar10_trainval_F22.zip
# Extracting ./data\cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified

# %%
INITIAL_LR = 0.1

# momentum for optimizer
MOMENTUM = 0.9

# L2 regularization strength
REG = 1e-4

# %%
def train_val(
    optimizer,
    criterion,
    model,
    train_loader=train_loader,
    val_loader=val_loader,
    device=device,
    INITIAL_LR=INITIAL_LR,
    REG=REG,
):
    # some hyperparameters
    # total number of training epochs

    EPOCHS = 30

    # the folder where the trained model is saved

    CHECKPOINT_FOLDER = "./saved_model"

    # start the training/validation process

    # the process should take about 5 minutes on a GTX 1070-Ti
    # if the code is written efficiently.
    best_val_acc = 0

    current_learning_rate = INITIAL_LR

    print("==> Training starts!")
    print("=" * 50)

    for i in range(0, EPOCHS):
        #######################

        # your code here
        # switch to train mode
        model.train()
        #######################

        print("Epoch %d:" % i)
        # this help you compute the training accuracy
        total_examples = 0
        correct_examples = 0

        train_loss = 0  # track training loss if you want

        # Train the model for 1 epoch.

        for batch_idx, (inputs, targets) in enumerate(train_loader):
            ####################################

            # your code here
            # copy inputs to device
            inputs, targets = inputs.to(device), targets.to(device)
            # compute the output and loss

            outputs = model(inputs)
            loss = criterion(outputs, targets)

            # zero the gradient

            optimizer.zero_grad()

            # backpropagation
            loss.backward()

            # apply gradient and update the weights
            optimizer.step()

            train_loss += loss.item()

            # count the number of correctly predicted samples in the current batch
            total_examples += targets.size(0)
            _, predicted = outputs.max(1)
            correct_examples += predicted.eq(targets).sum().item()
            ####################################

        print(
            f"CUDA memory allocated: {torch.cuda.memory_allocated(device) / 1e6:.2f} MB"
        )
        avg_loss = train_loss / len(train_loader)
        avg_acc = correct_examples / total_examples
        print("Training loss: %.4f, Training accuracy: %.4f" % (avg_loss, avg_acc))

        # Validate on the validation dataset
        #######################

        # your code here
        # switch to eval mode
        model.eval()

        #######################

        # this help you compute the validation accuracy
        total_examples = 0
        correct_examples = 0

        val_loss = 0  # again, track the validation loss if you want

        # disable gradient during validation, which can save GPU memory

        with torch.no_grad():
            for batch_idx, (inputs, targets) in enumerate(val_loader):
                ####################################

                # your code here
                # copy inputs to device
                inputs, targets = inputs.to(device), targets.to(device)
                # compute the output and loss

                outputs = model(inputs)
                loss = criterion(outputs, targets)

                # count the number of correctly predicted samples in the current batch

                total_examples += targets.size(0)
                _, predicted = outputs.max(1)
                correct_examples += predicted.eq(targets).sum().item()
                val_loss += loss.item()
                ####################################

        avg_loss = val_loss / len(val_loader)
        avg_acc = correct_examples / total_examples

        print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))

        # save the model checkpoint

        if avg_acc > best_val_acc:
            best_val_acc = avg_acc

            if not os.path.exists(CHECKPOINT_FOLDER):
                os.makedirs(CHECKPOINT_FOLDER)
            print("Saving ...")

            state = {
                "state_dict": model.state_dict(),
                "epoch": i,
                "lr": current_learning_rate,
            }
            checkpoint_path = os.path.join(
                CHECKPOINT_FOLDER, f"LR{INITIAL_LR}_REG{REG}.pth"
            )
            torch.save(state, checkpoint_path)

        print("")

    print("=" * 50)

    print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")

# %%
for lr in LR_LIST:
    model = SimpleNN().to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(
        model.parameters(), lr=lr, momentum=MOMENTUM, weight_decay=REG
    )
    print(f"Training with learning rate: {lr}")
    train_val(optimizer, criterion, model, INITIAL_LR=lr)
for reg in REG_LIST:
    model = SimpleNN().to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(
        model.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=reg
    )
    print(f"Training with regularization strength: {reg}")
    train_val(optimizer, criterion, model, REG=reg)
# Out:
# Training with learning rate: 1.0
# ==> Training starts!
# ==================================================
# Epoch 0:
# CUDA memory allocated: 18.93 MB
# Training loss: nan, Training accuracy: 0

# CUDA memory allocated: 18.93 MB
# Training loss: 0.9567, Training accuracy: 0.6629
# Validation loss: 0.9122, Validation accuracy: 0.6730
# Saving ...
#
# Epoch 13:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.9388, Training accuracy: 0.6678
# Validation loss: 0.8736, Validation accuracy: 0.6878
# Saving ...
#
# Epoch 14:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.9213, Training accuracy: 0.6736
# Validation loss: 0.8626, Validation accuracy: 0.7000
# Saving ...
#
# Epoch 15:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.9129, Training accuracy: 0.6780
# Validation loss: 0.8578, Validation accuracy: 0.6884
#
# Epoch 16:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8944, Training accuracy: 0.6861
# Validation loss: 0.8494, Validation accuracy: 0.6982
#
# Epoch 17:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8894, Training accuracy: 0.6849
# Validation loss: 0.8620, Validation accuracy: 0.6940
#
# Epoch 18:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8738, Training accuracy: 0.6907
# Validation loss: 0.8315, Validation accuracy: 0.6998
#
# Epoch 19:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8766, Training accuracy: 0.6898
# Validation loss: 0.8588, Validation accuracy: 0.6992
#
# Epoch 20:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8561, Training accuracy: 0.6992
# Validation loss: 0.8389, Validation accuracy: 0.7036
# Saving ...
#
# Epoch 21:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8460, Training accuracy: 0.7003
# Validation loss: 0.8259, Validation accuracy: 0.7076
# Saving ...
#
# Epoch 22:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8354, Training accuracy: 0.7016
# Validation loss: 0.7927, Validation accuracy: 0.7172
# Saving ...
#
# Epoch 23:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8314, Training accuracy: 0.7074
# Validation loss: 0.8105, Validation accuracy: 0.7188
# Saving ...
#
# Epoch 24:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8252, Training accuracy: 0.7101
# Validation loss: 0.8085, Validation accuracy: 0.7158
#
# Epoch 25:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8193, Training accuracy: 0.7115
# Validation loss: 0.7719, Validation accuracy: 0.7270
# Saving ...
#
# Epoch 26:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8063, Training accuracy: 0.7149
# Validation loss: 0.8032, Validation accuracy: 0.7102
#
# Epoch 27:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8033, Training accuracy: 0.7150
# Validation loss: 0.7601, Validation accuracy: 0.7354
# Saving ...
#
# Epoch 28:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8015, Training accuracy: 0.7174
# Validation loss: 0.7654, Validation accuracy: 0.7290
#
# Epoch 29:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.7925, Training accuracy: 0.7205
# Validation loss: 0.7803, Validation accuracy: 0.7288
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.7354
# Training with regularization strength: 0.0
# ==> Training starts!
# ==================================================
# Epoch 0:
# CUDA memory allocated: 18.93 MB
# Training loss: 1.8270, Training accuracy: 0.3216
# Validation loss: 1.5048, Validation accuracy: 0.4486
# Saving ...
#
# Epoch 1:
# CUDA memory allocated: 18.93 MB
# Training loss: 1.4820, Training accuracy: 0.4556
# Validation loss: 1.3153, Validation accuracy: 0.5188
# Saving ...
#
# Epoch 2:
# CUDA memory allocated: 18.93 MB
# Training loss: 1.3588, Training accuracy: 0.5070
# Validation loss: 1.2277, Validation accuracy: 0.5606
# Saving ...
#
# Epoch 3:
# CUDA memory allocated: 18.93 MB
# Training loss: 1.2642, Training accuracy: 0.5450
# Validation loss: 1.1745, Validation accuracy: 0.5854
# Saving ...
#
# Epoch 4:
# CUDA memory allocated: 18.93 MB
# Training loss: 1.2060, Training accuracy: 0.5671
# Validation loss: 1.1182, Validation accuracy: 0.6054
# Saving ...
#
# Epoch 5:
# CUDA memory allocated: 18.93 MB
# Training loss: 1.1557, Training accuracy: 0.5867
# Validation loss: 1.1073, Validation accuracy: 0.6070
# Saving ...
#
# Epoch 6:
# CUDA memory allocated: 18.93 MB
# Training loss: 1.1207, Training accuracy: 0.5978
# Validation loss: 1.0560, Validation accuracy: 0.6288
# Saving ...
#
# Epoch 7:
# CUDA memory allocated: 18.93 MB
# Training loss: 1.0889, Training accuracy: 0.6159
# Validation loss: 1.0185, Validation accuracy: 0.6402
# Saving ...
#
# Epoch 8:
# CUDA memory allocated: 18.93 MB
# Training loss: 1.0601, Training accuracy: 0.6248
# Validation loss: 1.0591, Validation accuracy: 0.6244
#
# Epoch 9:
# CUDA memory allocated: 18.93 MB
# Training loss: 1.0400, Training accuracy: 0.6306
# Validation loss: 1.0036, Validation accuracy: 0.6462
# Saving ...
#
# Epoch 10:
# CUDA memory allocated: 18.93 MB
# Training loss: 1.0244, Training accuracy: 0.6364
# Validation loss: 0.9679, Validation accuracy: 0.6572
# Saving ...
#
# Epoch 11:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.9948, Training accuracy: 0.6463
# Validation loss: 0.9324, Validation accuracy: 0.6684
# Saving ...
#
# Epoch 12:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.9746, Training accuracy: 0.6541
# Validation loss: 0.9195, Validation accuracy: 0.6732
# Saving ...
#
# Epoch 13:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.9648, Training accuracy: 0.6583
# Validation loss: 0.9169, Validation accuracy: 0.6764
# Saving ...
#
# Epoch 14:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.9535, Training accuracy: 0.6630
# Validation loss: 0.9027, Validation accuracy: 0.6858
# Saving ...
#
# Epoch 15:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.9365, Training accuracy: 0.6681
# Validation loss: 0.8826, Validation accuracy: 0.6844
#
# Epoch 16:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.9243, Training accuracy: 0.6740
# Validation loss: 0.8773, Validation accuracy: 0.6862
# Saving ...
#
# Epoch 17:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.9116, Training accuracy: 0.6769
# Validation loss: 0.8704, Validation accuracy: 0.6894
# Saving ...
#
# Epoch 18:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.9004, Training accuracy: 0.6801
# Validation loss: 0.8769, Validation accuracy: 0.6894
#
# Epoch 19:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8933, Training accuracy: 0.6836
# Validation loss: 0.8499, Validation accuracy: 0.6998
# Saving ...
#
# Epoch 20:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8794, Training accuracy: 0.6913
# Validation loss: 0.8347, Validation accuracy: 0.7110
# Saving ...
#
# Epoch 21:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8710, Training accuracy: 0.6920
# Validation loss: 0.8561, Validation accuracy: 0.7018
#
# Epoch 22:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8677, Training accuracy: 0.6921
# Validation loss: 0.8326, Validation accuracy: 0.7098
#
# Epoch 23:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8555, Training accuracy: 0.6958
# Validation loss: 0.8262, Validation accuracy: 0.7084
#
# Epoch 24:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8535, Training accuracy: 0.6970
# Validation loss: 0.8047, Validation accuracy: 0.7192
# Saving ...
#
# Epoch 25:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8465, Training accuracy: 0.7003
# Validation loss: 0.8336, Validation accuracy: 0.7030
#
# Epoch 26:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8363, Training accuracy: 0.7048
# Validation loss: 0.7959, Validation accuracy: 0.7216
# Saving ...
#
# Epoch 27:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8284, Training accuracy: 0.7096
# Validation loss: 0.7910, Validation accuracy: 0.7266
# Saving ...
#
# Epoch 28:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8226, Training accuracy: 0.7087
# Validation loss: 0.8109, Validation accuracy: 0.7174
#
# Epoch 29:
# CUDA memory allocated: 18.93 MB
# Training loss: 0.8167, Training accuracy: 0.7097
# Validation loss: 0.8039, Validation accuracy: 0.7178
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.7266

# %% [markdown]
# # Bonus: with learning rate decay
#
# The following code can help you adjust the learning rate during training. You need to figure out how to incorporate this code into your training loop.
# ```python
#     if i % DECAY_EPOCHS == 0 and i != 0:
#         current_learning_rate = current_learning_rate * DECAY
#         for param_group in optimizer.param_groups:
#             param_group['lr'] = current_learning_rate
#         print("Current learning rate has decayed to %f" %current_learning_rate)
# ```
